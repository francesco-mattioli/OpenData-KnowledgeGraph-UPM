# %%
from rdflib import Graph, Namespace

# %%
graph = Graph()
graph.parse("rdf.ttl", format='ttl')
# Out:
# <Graph identifier=Nd5fd2d71174e4f949798c4242fc7056d (<class 'rdflib.graph.Graph'>)>

# %%
print(graph)
# Out:
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'Memory']].

# %%
from rdflib.plugins.sparql import prepareQuery
ns = Namespace("http://somewhere#")

query_text=("""
SELECT ?station ?latitude ?longitude WHERE {
    # ?station ont:hasStreetAddress ?address .
    # ?address geo:latitude ?latitude .
    # ?address geo:longitude ?longitude .
}
""")
q1 = prepareQuery(query_text)

for r in g.query(q1):
    print(r)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# C:\Users\TYMOTE~1\AppData\Local\Temp/ipykernel_8412/2112448226.py in <module>
#       9 }
#      10 """)
# ---> 11 q1 = prepareQuery(query_text)
#      12
#      13 for r in g.query(q1):
#
# ~\anaconda3\lib\site-packages\rdflib\plugins\sparql\processor.py in prepareQuery(queryString, initNs, base)
#      29     if initNs is None:
#      30         initNs = {}
# ---> 31     ret = translateQuery(parseQuery(queryString), base, initNs)
#      32     ret._original_args = (queryString, initNs, base)
#      33     return ret
#
# ~\anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in translateQuery(q, base, initNs)
#     932
#     933     # absolutize/resolve prefixes
# --> 934     q[1] = traverse(
#     935         q[1], visitPost=functools.partial(translatePName, prologue=prologue)
#     936     )
#
# ~\anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in traverse(tree, visitPre, visitPost, complete)
#     467     """
#     468     try:
# --> 469         r = _traverse(tree, visitPre, visitPost)
#     470         if complete is not None:
#     471             return complete
#
# ~\anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in _traverse(e, visitPre, visitPost)
#     424     elif isinstance(e, CompValue):
#     425         for k, val in e.items():
# --> 426             e[k] = _traverse(val, visitPre, visitPost)
#     427
#     428     # type error: Statement is unreachable
#
# ~\anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in _traverse(e, visitPre, visitPost)
#     424     elif isinstance(e, CompValue):
#     425         for k, val in e.items():
# --> 426             e[k] = _traverse(val, visitPre, visitPost)
#     427
#     428     # type error: Statement is unreachable
#
# ~\anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in _traverse(e, visitPre, visitPost)
#     417
#     418     if isinstance(e, (list, ParseResults)):
# --> 419         return [_traverse(x, visitPre, visitPost) for x in e]
#     420     # type error: Statement is unreachable
#     421     elif isinstance(e, tuple):  # type: ignore[unreachable]
#
# ~\anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in <listcomp>(.0)
#     417
#     418     if isinstance(e, (list, ParseResults)):
# --> 419         return [_traverse(x, visitPre, visitPost) for x in e]
#     420     # type error: Statement is unreachable
#     421     elif isinstance(e, tuple):  # type: ignore[unreachable]
#
# ~\anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in _traverse(e, visitPre, visitPost)
#     424     elif isinstance(e, CompValue):
#     425         for k, val in e.items():
# --> 426             e[k] = _traverse(val, visitPre, visitPost)
#     427
#     428     # type error: Statement is unreachable
#
# ~\anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in _traverse(e, visitPre, visitPost)
#     417
#     418     if isinstance(e, (list, ParseResults)):
# --> 419         return [_traverse(x, visitPre, visitPost) for x in e]
#     420     # type error: Statement is unreachable
#     421     elif isinstance(e, tuple):  # type: ignore[unreachable]
#
# ~\anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in <listcomp>(.0)
#     417
#     418     if isinstance(e, (list, ParseResults)):
# --> 419         return [_traverse(x, visitPre, visitPost) for x in e]
#     420     # type error: Statement is unreachable
#     421     elif isinstance(e, tuple):  # type: ignore[unreachable]
#
# ~\anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in _traverse(e, visitPre, visitPost)
#     417
#     418     if isinstance(e, (list, ParseResults)):
# --> 419         return [_traverse(x, visitPre, visitPost) for x in e]
#     420     # type error: Statement is unreachable
#     421     elif isinstance(e, tuple):  # type: ignore[unreachable]
#
# ~\anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in <listcomp>(.0)
#     417
#     418     if isinstance(e, (list, ParseResults)):
# --> 419         return [_traverse(x, visitPre, visitPost) for x in e]
#     420     # type error: Statement is unreachable
#     421     elif isinstance(e, tuple):  # type: ignore[unreachable]
#
# ~\anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in _traverse(e, visitPre, visitPost)
#     424     elif isinstance(e, CompValue):
#     425         for k, val in e.items():
# --> 426             e[k] = _traverse(val, visitPre, visitPost)
#     427
#     428     # type error: Statement is unreachable
#
# ~\anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in _traverse(e, visitPre, visitPost)
#     417
#     418     if isinstance(e, (list, ParseResults)):
# --> 419         return [_traverse(x, visitPre, visitPost) for x in e]
#     420     # type error: Statement is unreachable
#     421     elif isinstance(e, tuple):  # type: ignore[unreachable]
#
# ~\anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in <listcomp>(.0)
#     417
#     418     if isinstance(e, (list, ParseResults)):
# --> 419         return [_traverse(x, visitPre, visitPost) for x in e]
#     420     # type error: Statement is unreachable
#     421     elif isinstance(e, tuple):  # type: ignore[unreachable]
#
# ~\anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in _traverse(e, visitPre, visitPost)
#     424     elif isinstance(e, CompValue):
#     425         for k, val in e.items():
# --> 426             e[k] = _traverse(val, visitPre, visitPost)
#     427
#     428     # type error: Statement is unreachable
#
# ~\anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in _traverse(e, visitPre, visitPost)
#     417
#     418     if isinstance(e, (list, ParseResults)):
# --> 419         return [_traverse(x, visitPre, visitPost) for x in e]
#     420     # type error: Statement is unreachable
#     421     elif isinstance(e, tuple):  # type: ignore[unreachable]
#
# ~\anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in <listcomp>(.0)
#     417
#     418     if isinstance(e, (list, ParseResults)):
# --> 419         return [_traverse(x, visitPre, visitPost) for x in e]
#     420     # type error: Statement is unreachable
#     421     elif isinstance(e, tuple):  # type: ignore[unreachable]
#
# ~\anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in _traverse(e, visitPre, visitPost)
#     424     elif isinstance(e, CompValue):
#     425         for k, val in e.items():
# --> 426             e[k] = _traverse(val, visitPre, visitPost)
#     427
#     428     # type error: Statement is unreachable
#
# ~\anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in _traverse(e, visitPre, visitPost)
#     427
#     428     # type error: Statement is unreachable
# --> 429     _e = visitPost(e)  # type: ignore[unreachable]
#     430     if _e is not None:
#     431         return _e
#
# ~\anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in translatePName(p, prologue)
#     195         if p.name == "pname":
#     196             # type error: Incompatible return value type (got "Union[CompValue, str, None]", expected "Optional[Identifier]")
# --> 197             return prologue.absolutize(p)  # type: ignore[return-value]
#     198         if p.name == "literal":
#     199             # type error: Argument "datatype" to "Literal" has incompatible type "Union[CompValue, str, None]"; expected "Optional[str]"
#
# ~\anaconda3\lib\site-packages\rdflib\plugins\sparql\sparql.py in absolutize(self, iri)
#     439         if isinstance(iri, CompValue):
#     440             if iri.name == "pname":
# --> 441                 return self.resolvePName(iri.prefix, iri.localname)
#     442             if iri.name == "literal":
#     443                 # type error: Argument "datatype" to "Literal" has incompatible type "Union[CompValue, Identifier, None]"; expected "Optional[str]"
#
# ~\anaconda3\lib\site-packages\rdflib\plugins\sparql\sparql.py in resolvePName(self, prefix, localname)
#     421         ns = self.namespace_manager.store.namespace(prefix or "")
#     422         if ns is None:
# --> 423             raise Exception("Unknown namespace prefix : %s" % prefix)
#     424         return URIRef(ns + (localname or ""))
#     425
#
# Exception: Unknown namespace prefix : ont
